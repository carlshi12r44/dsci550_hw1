# %%
import pandas as pd
import os
import json

if __name__=="__main__":
    file_path = os.getcwd() + "/email_context_part6_complete.json"
    
    with open(file_path, 'r') as out:
        hw_dict = json.load(out)
    actual_dict = {}
    for key in hw_dict.keys():
        if key == 'GDPPerCapita' or key == 'UnversityAndEduDomains' or key == 'MaliciousUrls':
            continue
        actual_dict[int(key)] = hw_dict[key]

    dataframe = pd.DataFrame.from_dict({(int(i)):actual_dict[i] for i in actual_dict.keys()}, orient='index')
    
#     dataframe = dataframe.dropna(axis=1)

# %%
len(dataframe.columns)
# Out:
# 1557

# %%
dataframe_for_extraction = dataframe[['Author','Content-Type', 'X-Parsed-By', 'X-TIKA:content',
       'X-TIKA:content_handler', 'X-TIKA:embedded_depth','Message-From','MboxParser-reply-to','Message-To','Message:Raw-Header:Reply-To',
       'X-TIKA:embedded_resource_path', 'X-TIKA:parse_time_millis',
       'isReconnaissance', 'isSocialEngineering', 'isMalware',
       'isCredentialPhishing', 'isAttackerSuperior', 'isUrgent',
       'attackerOffer', 'locations', 'relationships', 'sentiment',
       'misspellings', 'randomCaps', 'fraudScore', 'gdpPerCapitaPerCountry',
       'emailSenderAge','urls','anyUrlsInContent','numbersOfUrls','areUrlsMalicious','createdAt','isReceiverFromEduOrUniversity']]

# %%
dataframe_for_extraction
# Out:
#                                                  Author    Content-Type  \
# 1     [MR. JAMES NGOLA., MR. JAMES NGOLA. <james_ngo...  message/rfc822
# 2     ["Mr. Ben Suleman" <bensul2004nng@spinfinder.c...  message/rfc822
# 3     ["PRINCE OBONG ELEME" <obong_715@epatra.com>, ...  message/rfc822
# 4     ["PRINCE OBONG ELEME" <obong_715@epatra.com>, ...  message/rfc822
# 5     ["Maryam Abacha" <m_abacha03@www.com>, Maryam ...  message/rfc822
# ...                                                 ...             ...
# 3985                                                NaN  message/rfc822
# 3993                                                NaN  message/rfc822
# 3996                                                NaN  message/rfc822
# 4010                                                NaN  message/rfc822
# 4029                                                NaN  message/rfc822
#
#                                             X-Parsed-By  \
# 1     [org.apache.tika.parser.DefaultParser, org.apa...
# 2     [org.apache.tika.parser.DefaultParser, org.apa...
# 3     [org.apache.tika.parser.DefaultParser, org.apa...
# 4     [org.apache.tika.parser.DefaultParser, org.apa...
# 5     [org.apache.tika.parser.DefaultParser, org.apa...
# ...                                                 ...
# 3985  [org.apache.tika.parser.DefaultParser, org.apa...
# 3993  [org.apache.tika.parser.DefaultParser, org.apa...
# 3996  [org.apache.tika.parser.DefaultParser, org.apa...
# 4010  [org.apache.tika.parser.DefaultParser, org.apa...
# 4029  [org.apache.tika.parser.DefaultParser, org.apa...
#
#                                          X-TIKA:content  \
# 1     FROM:MR. JAMES NGOLA.\nCONFIDENTIAL TEL: 233-2...
# 2     Dear Friend,\n\nI am Mr. Ben Suleman a custom ...
# 3     FROM HIS ROYAL MAJESTY (HRM) CROWN RULER OF EL...
# 4     FROM HIS ROYAL MAJESTY (HRM) CROWN RULER OF EL...
# 5     Dear sir, \n \nIt is with a heart full of hope...
# ...                                                 ...
# 3985  TASAKI-SHINJU MANUFACTURING COMPANY LTD.\nTrus...
# 3993                                                 \n
# 3996                                                 \n
# 4010  It is a great honour to write you, after sever...
# 4029  \nMr.Huang Chi-Lin\nBank SinoPac\nExecutive Vi...
#
#      X-TIKA:content_handler X-TIKA:embedded_depth  \
# 1       ToXMLContentHandler                     1
# 2       ToXMLContentHandler                     1
# 3       ToXMLContentHandler                     1
# 4       ToXMLContentHandler                     1
# 5       ToXMLContentHandler                     1
# ...                     ...                   ...
# 3985    ToXMLContentHandler                     1
# 3993    ToXMLContentHandler                     1
# 3996    ToXMLContentHandler                     1
# 4010    ToXMLContentHandler                     1
# 4029    ToXMLContentHandler                     1
#
#                                         Message-From  \
# 1     MR. JAMES NGOLA. <james_ngola2002@maktoob.com>
# 2     Mr. Ben Suleman <bensul2004nng@spinfinder.com>
# 3          PRINCE OBONG ELEME <obong_715@epatra.com>
# 4          PRINCE OBONG ELEME <obong_715@epatra.com>
# 5                 Maryam Abacha <m_abacha03@www.com>
# ...                                              ...
# 3985                                             NaN
# 3993                                             NaN
# 3996                                             NaN
# 4010                                             NaN
# 4029                                             NaN
#
#               MboxParser-reply-to  \
# 1     james_ngola2002@maktoob.com
# 2                             NaN
# 3            obong_715@epatra.com
# 4                             NaN
# 5              m_abacha03@www.com
# ...                           ...
# 3985                          NaN
# 3993                          NaN
# 3996                          NaN
# 4010              alchbak@oran.cc
# 4029                          NaN
#
#                                              Message-To  \
# 1          [webmaster@aclweb.org, webmaster@aclweb.org]
# 2                                            [R@M, R@M]
# 3          [webmaster@aclweb.org, webmaster@aclweb.org]
# 4          [webmaster@aclweb.org, webmaster@aclweb.org]
# 5                                            [R@M, R@M]
# ...                                                 ...
# 3985  [undisclosed-recipients:; , undisclosed-recipi...
# 3993  [onuoha5a2003@yahoo.co.jp In brief introductio...
# 3996  [resumes@collarini.com business with you in yo...
# 4010                                         [R@S, R@S]
# 4029  [undisclosed-recipients:;, undisclosed-recipie...
#
#       Message:Raw-Header:Reply-To  ... randomCaps fraudScore  \
# 1     james_ngola2002@maktoob.com  ...         31         -1
# 2                             NaN  ...          9         -1
# 3            obong_715@epatra.com  ...          8         -1
# 4                             NaN  ...          8         -1
# 5              m_abacha03@www.com  ...          4         -1
# ...                           ...  ...        ...        ...
# 3985                          NaN  ...         13         -1
# 3993                          NaN  ...          0         -1
# 3996                          NaN  ...          0         -1
# 4010              alchbak@oran.cc  ...          0         -1
# 4029                          NaN  ...          7         -1
#
#       gdpPerCapitaPerCountry  emailSenderAge  urls  anyUrlsInContent  \
# 1                   -1.00000              30    []             False
# 2                   -1.00000              34    []             False
# 3                   -1.00000              36    []             False
# 4                   -1.00000              34    []             False
# 5                   -1.00000              33    []             False
# ...                      ...             ...   ...               ...
# 3985             65297.51751              39    []             False
# 3993             40246.88013              40    []             False
# 3996                -1.00000              33    []             False
# 4010                -1.00000              39    []             False
# 4029             65297.51751              35    []             False
#
#       numbersOfUrls  areUrlsMalicious              createdAt  \
# 1               0.0              -1.0  10/31/2002 (02:38:20)
# 2               0.0              -1.0  10/31/2002 (13:10:00)
# 3               0.0              -1.0  10/31/2002 (21:17:55)
# 4               0.0              -1.0  11/01/2002 (06:44:20)
# 5               0.0              -1.0  11/01/2002 (00:45:04)
# ...             ...               ...                    ...
# 3985            0.0              -1.0  08/22/2007 (20:54:03)
# 3993            0.0              -1.0  08/25/2007 (06:05:43)
# 3996            0.0              -1.0  08/28/2007 (11:31:35)
# 4010            0.0              -1.0  09/06/2007 (17:29:30)
# 4029            0.0              -1.0  09/19/2007 (13:41:32)
#
#      isReceiverFromEduOrUniversity
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# 5                            False
# ...                            ...
# 3985                         False
# 3993                         False
# 3996                         False
# 4010                         False
# 4029                         False
#
# [3999 rows x 33 columns]

# %%
dataframe_for_extraction.to_csv("data.tsv",sep="\t",index=False)
